# %%
# If you directly want pandas functions to be accessible as functions, do
from pandas import *

# %%
# %ls
# Out:
# 01_fundas.ipynb*      Indexing.ipynb*             Randomness.ipynb*
# 02_series.ipynb*      iris.csv*                   sample_data.txt*
# 03_dataframes.ipynb*  movies.csv*                 Strings.ipynb*
# 04_datetime.ipynb*    movies_exp.ipynb*           Untitled.ipynb*
# csv.ipynb*            movies.py*                  vectors.py*
# default.ipynb*        Pandas Introduction.ipynb*
# dirty.csv*            published/

# %%
movies = read_csv("movies.csv")

# %%
options.display.max_rows
# Out:
# 60

# %%
# Set the options to display max rows of a dataframe as 4000
options.display.max_rows = 4000

# %%
movies.shape
# Out:
# (3883, 4)

# %%
movies
# Out:
#       Unnamed: 0  movie_id                                              title  \
# 0              0         1                                   Toy Story (1995)
# 1              1         2                                     Jumanji (1995)
# 2              2         3                            Grumpier Old Men (1995)
# 3              3         4                           Waiting to Exhale (1995)
# 4              4         5                 Father of the Bride Part II (1995)
# 5              5         6                                        Heat (1995)
# 6              6         7                                     Sabrina (1995)
# 7              7         8                                Tom and Huck (1995)
# 8              8         9                                Sudden Death (1995)
# 9              9        10                                   GoldenEye (1995)
# 10            10        11                     American President, The (1995)
# ...
